# %% [markdown]
# <a href="https://colab.research.google.com/github/templehendrickson/biopharm_catalyst_project/blob/main/GradientBoosterTuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sklearn

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import GradientBoostingClassifier

# %%
trainingData = pd.read_csv('trainingData.csv')

# %%
trainingData.head()
# Out:
#         var_0  var_103       var_1  ...  var_77  var_84  targetLabels
# 0   63.000000    15.10  128.828611  ...       0       0             1
# 1    0.000000    17.02  180.000000  ...      10       0             0
# 2  113.000000    23.50   90.000000  ...       0      32             1
# 3   26.000000    27.50   59.000000  ...       0       4             0
# 4  110.689352    28.06   28.000000  ...       4      20             0
#
# [5 rows x 21 columns]

# %%
xTrain = trainingData.drop('targetLabels',axis=1).values
yTrain = trainingData['targetLabels'].values

# %%
gbc = GradientBoostingClassifier()
params = {
    'n_estimators':[5,50,250,500],
    'max_depth':[1,3,5,7,9],
    'learning_rate':[0.01,0.1,1,10,100]
}

from sklearn.model_selection import GridSearchCV
cv = GridSearchCV(gbc,params,cv=5,verbose=2)
cv.fit(xTrain,yTrain)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] learning_rate=0.01, max_depth=1, n_estimators=5 .................
# [CV] .. learning_rate=0.01, max_depth=1, n_estimators=5, total=   0.1s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=5 .................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] .. learning_rate=0.01, max_depth=1, n_estimators=5, total=   0.1s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=5 .................
# [CV] .. learning_rate=0.01, max_depth=1, n_estimators=5, total=   0.1s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=5 .................
# [CV] .. learning_rate=0.01, max_depth=1, n_estimators=5, total=   0.1s
# [CV] learning_rate=0.01, max_depth=1, n_estimators=5 .................
# [CV] .. learning_rate=0.01, max_depth=1, n_estimators=5, total=   0.1s
# ...

# %%
cv.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 250}
